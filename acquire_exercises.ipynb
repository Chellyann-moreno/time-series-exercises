# %%
import pandas as pd
import requests

# %% [markdown]
# 1. Using the code from the lesson as a guide and the REST API from https://swapi.dev/ as we did in the lesson, create a dataframe named people that has all of the data for people.
# 2. Do the same thing, but for planets.
# 3. Extract the data for starships.
# 4. Save the data in your files to local csv files so that it will be faster to access in the future.
# 5. Combine the data from your three separate dataframes into one large dataframe.
#
# 6. Acquire the Open Power Systems Data for Germany, which has been rapidly expanding its renewable energy production in recent years. The data set includes country-wide totals of electricity consumption, wind power production, and solar power production for 2006-2017. You can get the data here: https://raw.githubusercontent.com/jenfly/opsd/master/opsd_germany_daily.csv
#
# 7. Make sure all the work that you have done above is reproducible. That is, you should put the code above into separate functions in the acquire.py file and be able to re-run the functions and get the same data.

# %%
url='https://swapi.dev/api'

# %%
def get_data_from_api(url):
    data = []
    while True:
        response = requests.get(url)
        if response.status_code == 200:
            json_data = response.json()
            results = json_data['results']
            data.extend(results)
            url = json_data['next']
            if url is None:
                break
        else:
            print(f"Error: {response.status_code}")
            break
    return data

# %%
def save_data_as_csv(data, filename):
    df = pd.DataFrame(data)
    df.reset_index(drop=True, inplace=True)  # Reset index
    df.to_csv(filename, index=False)

# %%
def fetch_data_from_api(base_url, endpoint, filename):
    url = f"{base_url}/{endpoint}/"
    data = get_data_from_api(url)
    save_data_as_csv(data, filename)

# %%
fetch_data_from_api(url,'people','star_wars_people.csv')

# %%
people = pd.read_csv('star_wars_people.csv')
people.shape
# Out:
# (82, 16)

# %%
people.head()
# Out:
#              name height mass hair_color   skin_color eye_color birth_year  \
# 0  Luke Skywalker    172   77      blond         fair      blue      19BBY
# 1           C-3PO    167   75        NaN         gold    yellow     112BBY
# 2           R2-D2     96   32        NaN  white, blue       red      33BBY
# 3     Darth Vader    202  136       none        white    yellow    41.9BBY
# 4     Leia Organa    150   49      brown        light     brown      19BBY
#
#    gender                         homeworld  \
# 0    male  https://swapi.dev/api/planets/1/
# 1     NaN  https://swapi.dev/api/planets/1/
# 2     NaN  https://swapi.dev/api/planets/8/
# 3    male  https://swapi.dev/api/planets/1/
# 4  female  https://swapi.dev/api/planets/2/
#
#                                                films  \
# 0  ['https://swapi.dev/api/films/1/', 'https://sw...
# 1  ['https://swapi.dev/api/films/1/', 'https://sw...
# 2  ['https://swapi.dev/api/films/1/', 'https://sw...
# 3  ['https://swapi.dev/api/films/1/', 'https://sw...
# 4  ['https://swapi.dev/api/films/1/', 'https://sw...
#
#                                 species  \
# 0                                    []
# 1  ['https://swapi.dev/api/species/2/']
# 2  ['https://swapi.dev/api/species/2/']
# 3                                    []
# 4                                    []
#
#                                             vehicles  \
# 0  ['https://swapi.dev/api/vehicles/14/', 'https:...
# 1                                                 []
# 2                                                 []
# 3                                                 []
# 4             ['https://swapi.dev/api/vehicles/30/']
#
#                                            starships  \
# 0  ['https://swapi.dev/api/starships/12/', 'https...
# 1                                                 []
# 2                                                 []
# 3            ['https://swapi.dev/api/starships/13/']
# 4                                                 []
#
#                        created                       edited  \
# 0  2014-12-09T13:50:51.644000Z  2014-12-20T21:17:56.891000Z
# 1  2014-12-10T15:10:51.357000Z  2014-12-20T21:17:50.309000Z
# 2  2014-12-10T15:11:50.376000Z  2014-12-20T21:17:50.311000Z
# 3  2014-12-10T15:18:20.704000Z  2014-12-20T21:17:50.313000Z
# 4  2014-12-10T15:20:09.791000Z  2014-12-20T21:17:50.315000Z
#
#                                url
# 0  https://swapi.dev/api/people/1/
# 1  https://swapi.dev/api/people/2/
# 2  https://swapi.dev/api/people/3/
# 3  https://swapi.dev/api/people/4/
# 4  https://swapi.dev/api/people/5/

# %%
fetch_data_from_api(url,'planets','star_wars_planet.csv')

# %%
planets = pd.read_csv('star_wars_planet.csv')
planets.shape
# Out:
# (60, 14)

# %%
planets.head()
# Out:
#        name rotation_period orbital_period diameter              climate  \
# 0  Tatooine              23            304    10465                 arid
# 1  Alderaan              24            364    12500            temperate
# 2  Yavin IV              24           4818    10200  temperate, tropical
# 3      Hoth              23            549     7200               frozen
# 4   Dagobah              23            341     8900                murky
#
#         gravity                             terrain surface_water  population  \
# 0    1 standard                              desert             1      200000
# 1    1 standard               grasslands, mountains            40  2000000000
# 2    1 standard                 jungle, rainforests             8        1000
# 3  1.1 standard  tundra, ice caves, mountain ranges           100     unknown
# 4           NaN                      swamp, jungles             8     unknown
#
#                                            residents  \
# 0  ['https://swapi.dev/api/people/1/', 'https://s...
# 1  ['https://swapi.dev/api/people/5/', 'https://s...
# 2                                                 []
# 3                                                 []
# 4                                                 []
#
#                                                films  \
# 0  ['https://swapi.dev/api/films/1/', 'https://sw...
# 1  ['https://swapi.dev/api/films/1/', 'https://sw...
# 2                 ['https://swapi.dev/api/films/1/']
# 3                 ['https://swapi.dev/api/films/2/']
# 4  ['https://swapi.dev/api/films/2/', 'https://sw...
#
#                        created                       edited  \
# 0  2014-12-09T13:50:49.641000Z  2014-12-20T20:58:18.411000Z
# 1  2014-12-10T11:35:48.479000Z  2014-12-20T20:58:18.420000Z
# 2  2014-12-10T11:37:19.144000Z  2014-12-20T20:58:18.421000Z
# 3  2014-12-10T11:39:13.934000Z  2014-12-20T20:58:18.423000Z
# 4  2014-12-10T11:42:22.590000Z  2014-12-20T20:58:18.425000Z
#
#                                 url
# 0  https://swapi.dev/api/planets/1/
# 1  https://swapi.dev/api/planets/2/
# 2  https://swapi.dev/api/planets/3/
# 3  https://swapi.dev/api/planets/4/
# 4  https://swapi.dev/api/planets/5/

# %%
fetch_data_from_api(url,'starships','star_wars_starship.csv')

# %%
starships= pd.read_csv('star_wars_starship.csv')

starships.shape
# Out:
# (36, 18)

# %%
def concatenate_csv_files(csv_files):
    dfs = []
    for file in csv_files:
        df = pd.read_csv(file)
        dfs.append(df)
    concatenated_df = pd.concat(dfs, ignore_index=True)
    return concatenated_df

# %%
files=['star_wars_people.csv','star_wars_planet.csv','star_wars_planet.csv']

# %%
df=concatenate_csv_files(files)
df.sample(n=10)
# Out:
#                 name height  mass hair_color           skin_color eye_color  \
# 13          Han Solo    180    80      brown                 fair     brown
# 62   Luminara Unduli    170  56.2      black               yellow      blue
# 185      Glee Anselm    NaN   NaN        NaN                  NaN       NaN
# 68        Zam Wesell    168    55     blonde  fair, green, yellow    yellow
# 169          unknown    NaN   NaN        NaN                  NaN       NaN
# 49        Mace Windu    188    84       none                 dark     brown
# 117         Dathomir    NaN   NaN        NaN                  NaN       NaN
# 167       Bestine IV    NaN   NaN        NaN                  NaN       NaN
# 136             Ojom    NaN   NaN        NaN                  NaN       NaN
# 147           Bespin    NaN   NaN        NaN                  NaN       NaN
#
#     birth_year  gender                          homeworld  \
# 13       29BBY    male  https://swapi.dev/api/planets/22/
# 62       58BBY  female  https://swapi.dev/api/planets/51/
# 185        NaN     NaN                                NaN
# 68     unknown  female  https://swapi.dev/api/planets/54/
# 169        NaN     NaN                                NaN
# 49       72BBY    male  https://swapi.dev/api/planets/42/
# 117        NaN     NaN                                NaN
# 167        NaN     NaN                                NaN
# 136        NaN     NaN                                NaN
# 147        NaN     NaN                                NaN
#
#                                                  films  ...  \
# 13   ['https://swapi.dev/api/films/1/', 'https://sw...  ...
# 62   ['https://swapi.dev/api/films/5/', 'https://sw...  ...
# 185                                                 []  ...
# 68                  ['https://swapi.dev/api/films/5/']  ...
# 169                                                 []  ...
# 49   ['https://swapi.dev/api/films/4/', 'https://sw...  ...
# 117                                                 []  ...
# 167                                                 []  ...
# 136                                                 []  ...
# 147                 ['https://swapi.dev/api/films/2/']  ...
#
#                                    url rotation_period orbital_period  \
# 13    https://swapi.dev/api/people/14/             NaN            NaN
# 62    https://swapi.dev/api/people/64/             NaN            NaN
# 185  https://swapi.dev/api/planets/44/              33            206
# 68    https://swapi.dev/api/people/70/             NaN            NaN
# 169  https://swapi.dev/api/planets/28/               0              0
# 49    https://swapi.dev/api/people/51/             NaN            NaN
# 117  https://swapi.dev/api/planets/36/              24            491
# 167  https://swapi.dev/api/planets/26/              26            680
# 136  https://swapi.dev/api/planets/55/         unknown        unknown
# 147   https://swapi.dev/api/planets/6/              12           5110
#
#     diameter              climate                                 gravity  \
# 13       NaN                  NaN                                     NaN
# 62       NaN                  NaN                                     NaN
# 185    15600  tropical, temperate                                       1
# 68       NaN                  NaN                                     NaN
# 169        0              unknown                                 unknown
# 49       NaN                  NaN                                     NaN
# 117    10480            temperate                                     0.9
# 167     6400            temperate                                 unknown
# 136  unknown               frigid                                 unknown
# 147   118000            temperate  1.5 (surface), 1 standard (Cloud City)
#
#                           terrain surface_water population  \
# 13                            NaN           NaN        NaN
# 62                            NaN           NaN        NaN
# 185  lakes, islands, swamps, seas            80  500000000
# 68                            NaN           NaN        NaN
# 169                       unknown       unknown    unknown
# 49                            NaN           NaN        NaN
# 117    forests, deserts, savannas       unknown       5200
# 167         rocky islands, oceans            98   62000000
# 136              oceans, glaciers           100  500000000
# 147                     gas giant             0    6000000
#
#                                              residents
# 13                                                 NaN
# 62                                                 NaN
# 185               ['https://swapi.dev/api/people/53/']
# 68                                                 NaN
# 169  ['https://swapi.dev/api/people/20/', 'https://...
# 49                                                 NaN
# 117               ['https://swapi.dev/api/people/44/']
# 167               ['https://swapi.dev/api/people/19/']
# 136               ['https://swapi.dev/api/people/71/']
# 147               ['https://swapi.dev/api/people/26/']
#
# [10 rows x 25 columns]

# %%
df.shape
# Out:
# (202, 25)

# %%
df.isnull().sum()
# Out:
# name                 0
# height             120
# mass               120
# hair_color         125
# skin_color         120
# eye_color          120
# birth_year         120
# gender             123
# homeworld          120
# films                0
# species            120
# vehicles           120
# starships          120
# created              0
# edited               0
# url                  0
# rotation_period     82
# orbital_period      82
# diameter            82
# climate             82
# gravity             84
# terrain             82
# surface_water       82
# population          82
# residents           82
# dtype: int64

# %%
df = pd.read_csv('opsd_germany_daily.csv')

# %%
#Power Consume Systems from Germany
df.head()
# Out:
#          Date  Consumption  Wind  Solar  Wind+Solar
# 0  2006-01-01     1069.184   NaN    NaN         NaN
# 1  2006-01-02     1380.521   NaN    NaN         NaN
# 2  2006-01-03     1442.533   NaN    NaN         NaN
# 3  2006-01-04     1457.217   NaN    NaN         NaN
# 4  2006-01-05     1477.131   NaN    NaN         NaN

# %%
df.shape
# Out:
# (4383, 5)

# %%
df.isnull().sum()
# Out:
# Date              0
# Consumption       0
# Wind           1463
# Solar          2195
# Wind+Solar     2196
# dtype: int64
