# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Using your store items data:
#
# 1. Convert date column to datetime format.
# 2. Plot the distribution of sale_amount and item_price.
# 3. Set the index to be the datetime variable.
# 4. Add a 'month' and 'day of week' column to your dataframe.
# 5. Add a column to your dataframe, sales_total, which is a derived from sale_amount (total items) and item_price.
# 6. Make sure all the work that you have done above is reproducible. That is, you should put the code above into separate functions and be able to re-run the functions and get the same results.

# %%
#Acquire data
df = pd.read_csv('ts_superstore.csv', index_col=0)

# %%
df.head(3)
# Out:
#    item  sale_amount                      sale_date  sale_id  store  \
# 0     1         13.0  Tue, 01 Jan 2013 00:00:00 GMT        1      1
# 1     1         11.0  Wed, 02 Jan 2013 00:00:00 GMT        2      1
# 2     1         14.0  Thu, 03 Jan 2013 00:00:00 GMT        3      1
#
#   item_brand  item_id                       item_name  item_price  \
# 0   Riceland        1  Riceland American Jazmine Rice        0.84
# 1   Riceland        1  Riceland American Jazmine Rice        0.84
# 2   Riceland        1  Riceland American Jazmine Rice        0.84
#
#     item_upc12   item_upc14           store_address   store_city  store_id  \
# 0  35200264013  35200264013  12125 Alamo Ranch Pkwy  San Antonio         1
# 1  35200264013  35200264013  12125 Alamo Ranch Pkwy  San Antonio         1
# 2  35200264013  35200264013  12125 Alamo Ranch Pkwy  San Antonio         1
#
#   store_state  store_zipcode
# 0          TX          78253
# 1          TX          78253
# 2          TX          78253

# %%
df.sale_date=df.sale_date.str.replace('00:00:00 GMT','')
df.sale_date=df.sale_date.str.strip()
df.sale_date=pd.to_datetime(df.sale_date,format='%a, %d %b %Y')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 913000 entries, 0 to 912999
# Data columns (total 16 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   item           913000 non-null  int64
#  1   sale_amount    913000 non-null  float64
#  2   sale_date      913000 non-null  datetime64[ns]
#  3   sale_id        913000 non-null  int64
#  4   store          913000 non-null  int64
#  5   item_brand     913000 non-null  object
#  6   item_id        913000 non-null  int64
#  7   item_name      913000 non-null  object
#  8   item_price     913000 non-null  float64
#  9   item_upc12     913000 non-null  int64
#  10  item_upc14     913000 non-null  int64
#  11  store_address  913000 non-null  object
#  12  store_city     913000 non-null  object
#  13  store_id       913000 non-null  int64
#  14  store_state    913000 non-null  object
#  15  store_zipcode  913000 non-null  int64
# dtypes: datetime64[ns](1), float64(2), int64(8), object(5)
# memory usage: 118.4+ MB

# %%
df.sale_amount.hist()
# Out:
# <AxesSubplot:>

# %%
df.item_price.hist()
# Out:
# <AxesSubplot:>

# %%
df=df.set_index('sale_date').sort_index()

# %%
df.head(3)
# Out:
#             item  sale_amount  sale_id  store          item_brand  item_id  \
# sale_date
# 2013-01-01     1         13.0        1      1            Riceland        1
# 2013-01-01    17         26.0   295813      3               Ducal       17
# 2013-01-01     7         32.0   125995     10  Twinings Of London        7
#
#                                                     item_name  item_price  \
# sale_date
# 2013-01-01                     Riceland American Jazmine Rice        0.84
# 2013-01-01                            Ducal Refried Red Beans        1.16
# 2013-01-01  Twinings Of London Classics Lady Grey Tea - 20 Ct        9.64
#
#              item_upc12   item_upc14            store_address   store_city  \
# sale_date
# 2013-01-01  35200264013  35200264013   12125 Alamo Ranch Pkwy  San Antonio
# 2013-01-01  88313590791  88313590791  2118 Fredericksburg Rdj  San Antonio
# 2013-01-01  70177154004  70177154004     8503 NW Military Hwy  San Antonio
#
#             store_id store_state  store_zipcode
# sale_date
# 2013-01-01         1          TX          78253
# 2013-01-01         3          TX          78201
# 2013-01-01        10          TX          78231

# %%
df['month'] = df.index.month_name()
df['day_of_week'] = df.index.day_name()

# %%
df.head(3)
# Out:
#             item  sale_amount  sale_id  store          item_brand  item_id  \
# sale_date
# 2013-01-01     1         13.0        1      1            Riceland        1
# 2013-01-01    17         26.0   295813      3               Ducal       17
# 2013-01-01     7         32.0   125995     10  Twinings Of London        7
#
#                                                     item_name  item_price  \
# sale_date
# 2013-01-01                     Riceland American Jazmine Rice        0.84
# 2013-01-01                            Ducal Refried Red Beans        1.16
# 2013-01-01  Twinings Of London Classics Lady Grey Tea - 20 Ct        9.64
#
#              item_upc12   item_upc14            store_address   store_city  \
# sale_date
# 2013-01-01  35200264013  35200264013   12125 Alamo Ranch Pkwy  San Antonio
# 2013-01-01  88313590791  88313590791  2118 Fredericksburg Rdj  San Antonio
# 2013-01-01  70177154004  70177154004     8503 NW Military Hwy  San Antonio
#
#             store_id store_state  store_zipcode    month day_of_week
# sale_date
# 2013-01-01         1          TX          78253  January     Tuesday
# 2013-01-01         3          TX          78201  January     Tuesday
# 2013-01-01        10          TX          78231  January     Tuesday

# %%
df.sale_amount
# Out:
# sale_date
# 2013-01-01    13.0
# 2013-01-01    26.0
# 2013-01-01    32.0
# 2013-01-01    45.0
# 2013-01-01    34.0
#               ...
# 2017-12-31    31.0
# 2017-12-31    22.0
# 2017-12-31    19.0
# 2017-12-31    59.0
# 2017-12-31    82.0
# Name: sale_amount, Length: 913000, dtype: float64

# %%
df.item_price
# Out:
# sale_date
# 2013-01-01    0.84
# 2013-01-01    1.16
# 2013-01-01    9.64
# 2013-01-01    4.39
# 2013-01-01    0.74
#               ...
# 2017-12-31    9.02
# 2017-12-31    0.60
# 2017-12-31    5.62
# 2017-12-31    7.52
# 2017-12-31    5.20
# Name: item_price, Length: 913000, dtype: float64

# %%
for col in df.columns:
    print(col)
    df[col].hist()
    plt.show()
# Out:
# item
# sale_amount
# sale_id
# store
# item_brand
# item_id
# item_name
# item_price
# item_upc12
# item_upc14
# store_address
# store_city
# store_id
# store_state
# store_zipcode
# month
# day_of_week

# %%
df['sales_total']=df.item_price+df.sale_amount

# %%
def store_data():
    """
    Reads the 'ts_superstore.csv' file and performs data preprocessing on it.

    Returns:
        df (DataFrame): Processed data frame containing sales data for a superstore.
    
    """
    df = pd.read_csv('ts_superstore.csv', index_col=0)
    df.columns = df.columns.str.lower()
    df.sale_date = df.sale_date.str.replace('00:00:00 GMT', '')
    df.sale_date = df.sale_date.str.strip()
    df.sale_date = pd.to_datetime(df.sale_date, format='%a, %d %b %Y')
    df = df.set_index('sale_date').sort_index()
    df['month'] = df.index.month
    df['month_name'] = df.index.month_name()
    df['day_of_week'] = df.index.day_name()
    df['sales_total'] = df.item_price + df.sale_amount
    return df

# %%
df=store_data()

# %%
df.head(3)
# Out:
#             item  sale_amount  sale_id  store          item_brand  item_id  \
# sale_date
# 2013-01-01     1         13.0        1      1            Riceland        1
# 2013-01-01    17         26.0   295813      3               Ducal       17
# 2013-01-01     7         32.0   125995     10  Twinings Of London        7
#
#                                                     item_name  item_price  \
# sale_date
# 2013-01-01                     Riceland American Jazmine Rice        0.84
# 2013-01-01                            Ducal Refried Red Beans        1.16
# 2013-01-01  Twinings Of London Classics Lady Grey Tea - 20 Ct        9.64
#
#              item_upc12   item_upc14            store_address   store_city  \
# sale_date
# 2013-01-01  35200264013  35200264013   12125 Alamo Ranch Pkwy  San Antonio
# 2013-01-01  88313590791  88313590791  2118 Fredericksburg Rdj  San Antonio
# 2013-01-01  70177154004  70177154004     8503 NW Military Hwy  San Antonio
#
#             store_id store_state  store_zipcode  month month_name day_of_week  \
# sale_date
# 2013-01-01         1          TX          78253      1    January     Tuesday
# 2013-01-01         3          TX          78201      1    January     Tuesday
# 2013-01-01        10          TX          78231      1    January     Tuesday
#
#             sales_total
# sale_date
# 2013-01-01        13.84
# 2013-01-01        27.16
# 2013-01-01        41.64

# %%
def plot_distributions(dataframe):
    """
    Generate distribution plots for each column in the given data frame.

    Args:
        dataframe (DataFrame): Input data frame containing numerical columns.

    Returns:
        None
    
    """
    for column in dataframe.columns:
        sns.histplot(data=dataframe, x=column, kde=True)
        plt.title(f"Distribution of {column}")
        plt.show()

# %%
def plot_one_distribution(dataframe, column):
    """
    Generate a distribution plot for a specific column of a data frame.

    Args:
        dataframe (DataFrame): Input data frame.
        column (str): Name of the column to plot.

    Returns:
        None
    
    """
    sns.histplot(data=dataframe, x=column, kde=True)
    plt.title(f"Distribution of {column}")
    plt.show()

# %%
plot_one_distribution(df,'sale_amount')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /var/folders/wd/5_z1tvw94pv9x2ld8p_0dl2r0000gn/T/ipykernel_55529/3246592212.py in <module>
# ----> 1 plot_one_distribution(df,'sale_amount')
#
# /var/folders/wd/5_z1tvw94pv9x2ld8p_0dl2r0000gn/T/ipykernel_55529/1054569942.py in plot_one_distribution(dataframe, column)
#      11
#      12     """
# ---> 13     sns.histplot(data=dataframe, x=column, kde=True)
#      14     plt.title(f"Distribution of {column}")
#      15     plt.show()
#
# /usr/local/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py in histplot(data, x, y, hue, weights, stat, bins, binwidth, binrange, discrete, cumulative, common_bins, common_norm, multiple, element, fill, shrink, kde, kde_kws, line_kws, thresh, pthresh, pmax, cbar, cbar_ax, cbar_kws, palette, hue_order, hue_norm, color, log_scale, legend, ax, **kwargs)
#    1460     if p.univariate:
#    1461
# -> 1462         p.plot_univariate_histogram(
#    1463             multiple=multiple,
#    1464             element=element,
#
# /usr/local/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py in plot_univariate_histogram(self, multiple, element, fill, common_norm, common_bins, shrink, kde, kde_kws, color, legend, line_kws, estimate_kws, **plot_kws)
#     416             kde_kws["cumulative"] = estimate_kws["cumulative"]
#     417             log_scale = self._log_scaled(self.data_variable)
# --> 418             densities = self._compute_univariate_density(
#     419                 self.data_variable,
#     420                 common_norm,
#
# /usr/local/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py in _compute_univariate_density(self, data_variable, common_norm, common_grid, estimate_kws, log_scale, warn_singular)
#     301         densities = {}
#     302
# --> 303         for sub_vars, sub_data in self.iter_data("hue", from_comp_data=True):
#     304
#     305             # Extract the data points from this sub set and remove nulls
#
# /usr/local/anaconda3/lib/python3.9/site-packages/seaborn/_core.py in iter_data(self, grouping_vars, reverse, from_comp_data)
#     981
#     982         if from_comp_data:
# --> 983             data = self.comp_data
#     984         else:
#     985             data = self.plot_data
#
# /usr/local/anaconda3/lib/python3.9/site-packages/seaborn/_core.py in comp_data(self)
#    1055                     orig = self.plot_data[var].dropna()
#    1056                 comp_col = pd.Series(index=orig.index, dtype=float, name=var)
# -> 1057                 comp_col.loc[orig.index] = pd.to_numeric(axis.convert_units(orig))
#    1058
#    1059                 if axis.get_scale() == "log":
#
# /usr/local/anaconda3/lib/python3.9/site-packages/pandas/core/indexing.py in __setitem__(self, key, value)
#     710         else:
#     711             key = com.apply_if_callable(key, self.obj)
# --> 712         indexer = self._get_setitem_indexer(key)
#     713         self._has_valid_setitem_indexer(key)
#     714
#
# /usr/local/anaconda3/lib/python3.9/site-packages/pandas/core/indexing.py in _get_setitem_indexer(self, key)
#     664             return list(key)
#     665
# --> 666         return self._convert_to_indexer(key, axis=0)
#     667
#     668     def _ensure_listlike_indexer(self, key, axis=None, value=None):
#
# /usr/local/anaconda3/lib/python3.9/site-packages/pandas/core/indexing.py in _convert_to_indexer(self, key, axis)
#    1292                 return inds
#    1293             else:
# -> 1294                 return self._get_listlike_indexer(key, axis)[1]
#    1295         else:
#    1296             try:
#
# /usr/local/anaconda3/lib/python3.9/site-packages/pandas/core/indexing.py in _get_listlike_indexer(self, key, axis)
#    1328         axis_name = self.obj._get_axis_name(axis)
#    1329
# -> 1330         keyarr, indexer = ax._get_indexer_strict(key, axis_name)
#    1331
#    1332         return keyarr, indexer
#
# /usr/local/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py in _get_indexer_strict(self, key, axis_name)
#    5792             keyarr = self.reindex(keyarr)[0]
#    5793         else:
# -> 5794             keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
#    5795
#    5796         self._raise_if_missing(keyarr, indexer, axis_name)
#
# /usr/local/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py in _reindex_non_unique(self, target)
#    4274             return self[:0], np.array([], dtype=np.intp), None
#    4275
# -> 4276         indexer, missing = self.get_indexer_non_unique(target)
#    4277         check = indexer != -1
#    4278         new_labels = self.take(indexer[check])
#
# /usr/local/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py in get_indexer_non_unique(self, target)
#    5753             )
#    5754
# -> 5755         indexer, missing = self._engine.get_indexer_non_unique(tgt_values)
#    5756         return ensure_platform_int(indexer), ensure_platform_int(missing)
#    5757
#
# /usr/local/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_indexer_non_unique()
#
# <__array_function__ internals> in resize(*args, **kwargs)
#
# /usr/local/anaconda3/lib/python3.9/site-packages/numpy/core/fromnumeric.py in resize(a, new_shape)
#    1430
#    1431     repeats = -(-new_size // a.size)  # ceil division
# -> 1432     a = concatenate((a,) * repeats)[:new_size]
#    1433
#    1434     return reshape(a, new_shape)
#
# <__array_function__ internals> in concatenate(*args, **kwargs)
#
# KeyboardInterrupt:

# %% [markdown]
# ### Using the OPS data acquired in the Acquire exercises opsd_germany_daily.csv, complete the following:
#
# 1. Convert date column to datetime format.
# 2. Plot the distribution of each of your variables.
# 3. Set the index to be the datetime variable.
# 4. Add a month and a year column to your dataframe.
# 5. Fill any missing values.
# 6. Make sure all the work that you have done above is reproducible. That is, you should put the code above into separate functions and be able to       re-run the functions and get the same results.

# %%
#Acquire Data
df = pd.read_csv('opsd_germany_daily.csv')

# %%
df.head()
# Out:
#          Date  Consumption  Wind  Solar  Wind+Solar
# 0  2006-01-01     1069.184   NaN    NaN         NaN
# 1  2006-01-02     1380.521   NaN    NaN         NaN
# 2  2006-01-03     1442.533   NaN    NaN         NaN
# 3  2006-01-04     1457.217   NaN    NaN         NaN
# 4  2006-01-05     1477.131   NaN    NaN         NaN

# %%
df.columns=df.columns.str.lower()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4383 entries, 0 to 4382
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   date         4383 non-null   object
#  1   consumption  4383 non-null   float64
#  2   wind         2920 non-null   float64
#  3   solar        2188 non-null   float64
#  4   wind+solar   2187 non-null   float64
# dtypes: float64(4), object(1)
# memory usage: 171.3+ KB

# %%
for col in df.columns:
    print(col)
    df[col].hist()
    plt.show()
# Out:
# date
# consumption
# wind
# solar
# wind+solar

# %%
plot_distributions(df)

# %%
df.date=df.date.astype('datetime64')

# %%
df=df.set_index('date')

# %%
df['month'] = df.index.month_name()
df['year'] = df.index.year

# %%
df.head(3)
# Out:
#             consumption  wind  solar  wind+solar    month  year
# date
# 2006-01-01     1069.184   NaN    NaN         NaN  January  2006
# 2006-01-02     1380.521   NaN    NaN         NaN  January  2006
# 2006-01-03     1442.533   NaN    NaN         NaN  January  2006

# %%
df.isnull().sum()

# %%
df = df.bfill()

# %%
df.isnull().sum()

# %%
def opsd_data():
    """
    Reads the 'opsd_germany_daily.csv' file and performs data preprocessing on it.

    Returns:
        df (DataFrame): Processed data frame containing daily electricity consumption and production data for Germany.
    
    """
    df = pd.read_csv('opsd_germany_daily.csv')
    df.columns = df.columns.str.lower()
    df.date = df.date.astype('datetime64')
    df = df.set_index('date')
    df = df.sort_index()
    df['month'] = df.index.month
    df['month_name'] = df.index.month_name()
    df['year'] = df.index.year
    df = df.bfill()
    return df

# %%
opsd_data()
# Out:
#             consumption     wind   solar  wind+solar  month month_name  year
# date
# 2006-01-01   1069.18400   48.709   6.587     234.052      1    January  2006
# 2006-01-02   1380.52100   48.709   6.587     234.052      1    January  2006
# 2006-01-03   1442.53300   48.709   6.587     234.052      1    January  2006
# 2006-01-04   1457.21700   48.709   6.587     234.052      1    January  2006
# 2006-01-05   1477.13100   48.709   6.587     234.052      1    January  2006
# ...                 ...      ...     ...         ...    ...        ...   ...
# 2017-12-27   1263.94091  394.507  16.530     411.037     12   December  2017
# 2017-12-28   1299.86398  506.424  14.162     520.586     12   December  2017
# 2017-12-29   1295.08753  584.277  29.854     614.131     12   December  2017
# 2017-12-30   1215.44897  721.247   7.467     728.714     12   December  2017
# 2017-12-31   1107.11488  721.176  19.980     741.156     12   December  2017
#
# [4383 rows x 7 columns]
