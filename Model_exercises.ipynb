# %% [markdown]
# Using saas.csv
#
# 1. Split data (train/test) and resample by any period, except daily, and aggregate using the sum.
# 2. Forecast, plot and evaluate using each at least 4 of the methods we discussed:
#    - Last Observed Value
#    - Simple Average
#    - Moving Average
#    - Holt's Linear Trend
#    - Holt's Seasonal Trend
# 3. Based on previous year/month/etc., this is up to you.

# %%
import prepare as p

import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.api as sm

# working with dates
from datetime import datetime

# modeling
import statsmodels.api as sm
from statsmodels.tsa.api import Holt, ExponentialSmoothing

# evaluate
from sklearn.metrics import mean_squared_error
from math import sqrt

# %%
df = pd.read_csv('saas.csv')

# %%
df.head()
# Out:
#   Month_Invoiced  Customer_Id  Invoice_Id  Subscription_Type  Amount
# 0     2014-01-31      1000000     5000000                0.0     0.0
# 1     2014-01-31      1000001     5000001                2.0    10.0
# 2     2014-01-31      1000002     5000002                0.0     0.0
# 3     2014-01-31      1000003     5000003                0.0     0.0
# 4     2014-01-31      1000004     5000004                1.0     5.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 790458 entries, 0 to 790457
# Data columns (total 5 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   Month_Invoiced     790458 non-null  object
#  1   Customer_Id        790458 non-null  int64
#  2   Invoice_Id         790458 non-null  int64
#  3   Subscription_Type  790458 non-null  float64
#  4   Amount             790458 non-null  float64
# dtypes: float64(2), int64(2), object(1)
# memory usage: 30.2+ MB

# %%
df.Month_Invoiced = pd.to_datetime(df.Month_Invoiced)
df = df.set_index('Month_Invoiced').sort_index()

# %%
df = df.resample('d')[['Amount']].sum()

# %%
df.index.min(), df.index.max()
# Out:
# (Timestamp('2014-01-31 00:00:00', freq='D'),
#  Timestamp('2017-12-31 00:00:00', freq='D'))

# %%
for col in df.columns:
    print(col)
    df[col].hist()
    plt.show()
# Out:
# Amount

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/wd/5_z1tvw94pv9x2ld8p_0dl2r0000gn/T/ipykernel_60151/2750924244.py in <module>
# ----> 1 df = df.index.resample('d')[['Amount']].sum()
#
# AttributeError: 'Index' object has no attribute 'resample'

# %% [markdown]
# ### 1. Data split

# %%
train_size = int(len(df) * .5)
validate_size = int(len(df) * .3)
test_size = int(len(df) - train_size - validate_size)
validate_end_index = train_size + validate_size

# split into train, validation, test
train = df[: train_size]
validate = df[train_size : validate_end_index]
test = df[validate_end_index : ]

# %%
for col in train.columns:
    plt.figure(figsize=(12,4))
    plt.plot(train[col])
    plt.plot(validate[col])
    plt.plot(test[col])
    plt.ylabel(col)
    plt.title(col)
    plt.show()

# %% [markdown]
# ### 2. Forecast

# %%
# take the last item of sales total and assign to variable
last_amount = train['Amount'][-1:][0]


yhat_df = pd.DataFrame(
    {'total_amount': [last_amount]},
    index=validate.index)

yhat_df.head()
# Out:
#                 total_amount
# Month_Invoiced
# 2016-01-16               0.0
# 2016-01-17               0.0
# 2016-01-18               0.0
# 2016-01-19               0.0
# 2016-01-20               0.0

# %%
def plot_and_eval(target_var):
    '''
    This function takes in the target var name (string), and returns a plot
    of the values of train for that variable, validate, and the predicted values from yhat_df. 
    it will als lable the rmse. 
    '''
    plt.figure(figsize = (12,4))
    plt.plot(train[target_var], label = 'Train', linewidth = 1)
    plt.plot(validate[target_var], label = 'Validate', linewidth = 1)
    plt.plot(yhat_df[target_var])
    plt.title(target_var)
    rmse = evaluate(target_var)
    print(target_var, '-- RMSE: {:.0f}'.format(rmse))
    plt.show()

# %%
for col in train.columns:
    plot_and_eval(col)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3628             try:
# -> 3629                 return self._engine.get_loc(casted_key)
#    3630             except KeyError as err:
#
# /usr/local/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Amount'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /var/folders/wd/5_z1tvw94pv9x2ld8p_0dl2r0000gn/T/ipykernel_60151/2290735789.py in <module>
#       1 for col in train.columns:
# ----> 2     plot_and_eval(col)
#
# /var/folders/wd/5_z1tvw94pv9x2ld8p_0dl2r0000gn/T/ipykernel_60151/4051663250.py in plot_and_eval(target_var)
#       8     plt.plot(train[target_var], label = 'Train', linewidth = 1)
#       9     plt.plot(validate[target_var], label = 'Validate', linewidth = 1)
# ---> 10     plt.plot(yhat_df[target_var])
#      11     plt.title(target_var)
#      12     rmse = evaluate(target_var)
#
# /usr/local/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    3503             if self.columns.nlevels > 1:
#    3504                 return self._getitem_multilevel(key)
# -> 3505             indexer = self.columns.get_loc(key)
#    3506             if is_integer(indexer):
#    3507                 indexer = [indexer]
#
# /usr/local/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3629                 return self._engine.get_loc(casted_key)
#    3630             except KeyError as err:
# -> 3631                 raise KeyError(key) from err
#    3632             except TypeError:
#    3633                 # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: 'Amount'

# %%
def evaluate(target_var):
    '''
    This function will take the actual values of the target_var from validate, 
    and the predicted values stored in yhat_df, 
    and compute the rmse, rounding to 0 decimal places. 
    it will return the rmse. 
    '''
    rmse = round(sqrt(mean_squared_error(validate[target_var], yhat_df[target_var])), 0)
    return rmse

# %%
# function to store rmse for comparison purposes
def append_eval_df(model_type, target_var):
    '''
    this function takes in as arguments the type of model run, and the name of the target variable. 
    It returns the eval_df with the rmse appended to it for that model and target_var. 
    '''
    rmse = evaluate(target_var)
    d = {'model_type': [model_type], 'target_var': [target_var], 'rmse': [rmse]}
    d = pd.DataFrame(d)
    return pd.concat([eval_df, d])

# %%
for col in train.columns:
    eval_df = append_eval_df(model_type = 'last_observed_value', 
                             target_var = col)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3628             try:
# -> 3629                 return self._engine.get_loc(casted_key)
#    3630             except KeyError as err:
#
# /usr/local/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Amount'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /var/folders/wd/5_z1tvw94pv9x2ld8p_0dl2r0000gn/T/ipykernel_60151/3838829389.py in <module>
#       1 for col in train.columns:
# ----> 2     eval_df = append_eval_df(model_type = 'last_observed_value',
#       3                              target_var = col)
#
# /var/folders/wd/5_z1tvw94pv9x2ld8p_0dl2r0000gn/T/ipykernel_60151/1975658667.py in append_eval_df(model_type, target_var)
#       5     It returns the eval_df with the rmse appended to it for that model and target_var.
#       6     '''
# ----> 7     rmse = evaluate(target_var)
#       8     d = {'model_type': [model_type], 'target_var': [target_var], 'rmse': [rmse]}
#       9     d = pd.DataFrame(d)
#
# /var/folders/wd/5_z1tvw94pv9x2ld8p_0dl2r0000gn/T/ipykernel_60151/653392329.py in evaluate(target_var)
#       6     it will return the rmse.
#       7     '''
# ----> 8     rmse = round(sqrt(mean_squared_error(validate[target_var], yhat_df[target_var])), 0)
#       9     return rmse
#
# /usr/local/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    3503             if self.columns.nlevels > 1:
#    3504                 return self._getitem_multilevel(key)
# -> 3505             indexer = self.columns.get_loc(key)
#    3506             if is_integer(indexer):
#    3507                 indexer = [indexer]
#
# /usr/local/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3629                 return self._engine.get_loc(casted_key)
#    3630             except KeyError as err:
# -> 3631                 raise KeyError(key) from err
#    3632             except TypeError:
#    3633                 # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: 'Amount'
